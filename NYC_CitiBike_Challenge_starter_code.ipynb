# %%
import pandas as pd

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
file_1 = "2013-08 - Citi Bike trip data.csv"
file_2 = "2014-02 - Citi Bike trip data.csv"
df1 = pd.read_csv(file_1)
df2 = pd.read_csv(file_2)
# Out:
#         tripduration            starttime             stoptime  \
# 0                382  2014-02-01 00:00:00  2014-02-01 00:06:22
# 1                372  2014-02-01 00:00:03  2014-02-01 00:06:15
# 2                591  2014-02-01 00:00:09  2014-02-01 00:10:00
# 3                583  2014-02-01 00:00:32  2014-02-01 00:10:15
# 4                223  2014-02-01 00:00:41  2014-02-01 00:04:24
# ...              ...                  ...                  ...
# 224731           848  2014-02-28 23:57:13  2014-03-01 00:11:21
# 224732          1355  2014-02-28 23:57:55  2014-03-01 00:20:30
# 224733           304  2014-02-28 23:58:17  2014-03-01 00:03:21
# 224734           308  2014-02-28 23:59:10  2014-03-01 00:04:18
# 224735           603  2014-02-28 23:59:47  2014-03-01 00:09:50
#
#         start station id            start station name  \
# 0                    294           Washington Square E
# 1                    285            Broadway & E 14 St
# ...

# %%
# Merging dataframes
df_merged = pd.concat([df1, df2], ignore_index = True)
df_merged.head()
print(df_merged.columns)
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
# assuming that the tripduration column is in seconds
df_merged['tripminutes'] = df_merged['tripduration'] / 60
df_merged['tripminutes'] = df_merged['tripminutes'].round()

# move the tripminutes column to the beginning of the dataframe
cols = df_merged.columns.tolist()
cols = ['tripminutes'] + cols[:-1]
df_merged = df_merged[cols]
df_merged.tail()
# Out:
#          tripminutes  tripduration            starttime             stoptime  \
# 1226689         14.0           848  2014-02-28 23:57:13  2014-03-01 00:11:21
# 1226690         23.0          1355  2014-02-28 23:57:55  2014-03-01 00:20:30
# 1226691          5.0           304  2014-02-28 23:58:17  2014-03-01 00:03:21
# 1226692          5.0           308  2014-02-28 23:59:10  2014-03-01 00:04:18
# 1226693         10.0           603  2014-02-28 23:59:47  2014-03-01 00:09:50
#
#          start station id            start station name  \
# 1226689               498            Broadway & W 32 St
# 1226690               470               W 20 St & 8 Ave
# 1226691               497            E 17 St & Broadway
# 1226692               353    S Portland Ave & Hanson Pl
# 1226693               252  MacDougal St & Washington Sq
#
#          start station latitude  start station longitude  end station id  \
# 1226689               40.748549               -73.988084             432
# ...

# %%
# 2. Check the datatypes of your columns. 
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1226694 entries, 0 to 1226693
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   tripminutes              1226694 non-null  float64
#  1   tripduration             1226694 non-null  int64
#  2   starttime                1226694 non-null  object
#  3   stoptime                 1226694 non-null  object
#  4   start station id         1226694 non-null  int64
#  5   start station name       1226694 non-null  object
#  6   start station latitude   1226694 non-null  float64
#  7   start station longitude  1226694 non-null  float64
#  8   end station id           1226694 non-null  int64
#  9   end station name         1226694 non-null  object
#  10  end station latitude     1226694 non-null  float64
#  11  end station longitude    1226694 non-null  float64
#  12  bikeid                   1226694 non-null  int64
# ...

# %%
# 3. Convert the 'tripduration' column to datetime datatype.

df_merged["tripduration"] = pd.to_datetime(df_merged["tripduration"])

# %%
# 4. Check the datatypes of your columns. 
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1226694 entries, 0 to 1226693
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   tripminutes              1226694 non-null  float64
#  1   tripduration             1226694 non-null  datetime64[ns]
#  2   starttime                1226694 non-null  object
#  3   stoptime                 1226694 non-null  object
#  4   start station id         1226694 non-null  int64
#  5   start station name       1226694 non-null  object
#  6   start station latitude   1226694 non-null  float64
#  7   start station longitude  1226694 non-null  float64
#  8   end station id           1226694 non-null  int64
#  9   end station name         1226694 non-null  object
#  10  end station latitude     1226694 non-null  float64
#  11  end station longitude    1226694 non-null  float64
#  12  bikeid                   1226694 non-null  int64
# ...

# %%
# 5. Export the Dataframe as a new CSV file without the index.
df_merged.to_csv("merged.csv", index = False)
